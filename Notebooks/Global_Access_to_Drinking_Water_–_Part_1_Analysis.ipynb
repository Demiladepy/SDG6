# %% [markdown]
# #  Global Access to Drinking Water – Part 1 Analysis
# **Author:** Rediet
# **Project:** SDG 6 – Access to water
# **Dataset:** WHO/UNICEF JMP Estimates on the Use of Water (2020)
#
# ---
#
# ##  Objective
# This notebook investigates access to safe and affordable drinking water across national, urban, and rural areas using the 2020 JMP dataset. It answers five key questions and concludes with policy recommendations aligned with SDG 6.
#
# ---
#
# ## 1. 📊 How does the dataset population compare to world estimates?
#
# - **World population (2020):** 7.821 billion
# - **Dataset population (`pop_n`)** is in thousands → converted to billions
# - **Total dataset population:** 7.786 billion

# %% [markdown]
# > Add blockquote![Total Dataset National Population vs. Estimated world Population.png](data:image/png;base64,...)

# %% [markdown]
# The pie chart shows that the **Total Dataset National Population is nearly equal to the Estimated World Population** — a 49.9% vs. 50.1% split. This confirms that:
#
# - ✅ The dataset is **globally representative**, not a partial or biased sample.
# - ✅ The population coverage is **sufficiently comprehensive** to support policy analysis and recommendations.
# - ✅ Any insights drawn from this dataset — whether about **urbanization**, **service-level access**, or **income group disparities** — can be **scaled to global contexts**.
#
# ###  Policy Validation:
# This near-equal coverage validates the use of this dataset for:
# - Global benchmarking
# - Scalable infrastructure planning
# - Equitable water access policy design

# %% [markdown]
# ## 2.  What is the urban vs rural population share?
#
# ### 🔹 Chart: Line Chart of Urban vs. Rural Share by National Population Size
# ![National population vs urban and rural share.png](data:image/png;base64,...)

# %% [markdown]
# ### ✅ Interpretation:
# - Most countries show a **higher urban share** than rural, confirming global urbanization trends.
# - A few countries are **rural-dominant**, often correlating with lower access to basic water services.
# - The chart reveals **regional fluctuations**, but supports the global estimate that **55% of people live in urban areas**.
#
# ###  Policy Insight:
# - Urban areas tend to have better infrastructure and higher water access levels.
# - Rural-dominant countries may require **targeted infrastructure investment**.
# - This supports prioritizing **rural water access programs** in low-income regions.

# %% [markdown]
# ## 📈 Question 3: What are the tendencies and spreads of water access features?
#
# ### 🔹 Chart: Access to Water – Box Plot Comparison
#
# This box plot visualizes the five-number summary (min, Q1, median, Q3, max) for water access features across three area types: **National**, **Rural**, and **Urban**.

# %% [markdown]
# ![_Access to Water – Box Plot Comparison.png](data:image/png;base64,...)

# %% [markdown]
# ####  Interpretation:
# - **National access (`wat_bas_n`)** shows a high median and tight interquartile range → most countries have strong basic access nationally.
# - **Rural access (`wat_sur_r`, `wat_unimp_r`)** has wider spread and lower medians → rural areas face significant inequality and service gaps.
# - **Urban access (`wat_bas_u`)** is more consistent and skewed toward higher values → urban populations generally enjoy better access.
#
# ####  Statistical Tendencies:
# - Mean, median, and mode are not equal → distributions are skewed.
# - Standard deviation and IQR are higher in rural features → greater variability.
# - Surface water usage is more prevalent in rural areas, often exceeding 25% in some countries.
#
# ####  Policy Insight:
# - Rural areas require urgent infrastructure investment to reduce reliance on surface and unimproved water sources.
# - Urban models of access delivery can be adapted for rural deployment.
# - National averages can mask regional disparities — disaggregated analysis is essential for equitable planning.

# %% [markdown]
# ##  Question 4: How do water access measures vary by area type (national, urban, rural)?
#
# ### 🔹 Chart: National Water Access by Population Size
#
# This 100% stacked column chart displays the proportion of each water access type—**basic**, **limited**, **unimproved**, and **surface**—across countries grouped by national population size (in millions).

# %% [markdown]
# ![National Water Access by Population Size.png](data:image/png;base64,...)

# %% [markdown]
# ####  Interpretation:
# - **Basic access (red)** dominates in most population groups, especially in mid-sized and large countries.
# - **Surface water (blue)** and **unimproved access (green)** are more prevalent in countries with smaller populations, indicating infrastructure gaps.
# - **Limited access (orange)** fluctuates but tends to decrease as population size increases, suggesting better service delivery in larger nations.
#
# ####  Area Type Comparison:
# While this chart focuses on national-level data, it complements earlier visualizations:
# - **Urban areas** show higher and more consistent basic access.
# - **Rural areas** display wider variability and higher reliance on surface and unimproved sources.
# - **National averages** can mask these disparities — disaggregated analysis is essential.
#
# ####  Policy Insight:
# - Countries with **smaller populations** may lack the scale or resources for robust water infrastructure — these should be prioritized for international support.
# - **Larger countries** show better access but may still have internal rural disparities.

# %% [markdown]
# ### Question 5: What is the relationship between population size, urbanization, GNI, and water access?
#
# ### 🔹 Chart: Water Access and Urbanization by Income Group
#
# This bar chart compares total population (`pop_n`), urban share (`pop_u`), and water access levels (`wat_bas_n`, `wat_unimp_n`, `wat_sur_n`) across income groups.

# %% [markdown]
# ![Water Access and Urbanization by Income Group.png](data:image/png;base64,...)

# %% [markdown]
# ####  Interpretation:
# - **High-income countries** have high urbanization and near-universal basic water access.
# - **Low-income countries** show low urbanization and high reliance on unimproved and surface water.
# - **Lower-middle income countries** have moderate urbanization but still face access challenges.
# - **Upper-middle income countries** show strong urbanization and improving access levels.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🔹 Table: Summary Statistics by Income Group
#
# This pivot table includes:
# - Total population (`SUM of pop_n`)
# - Average urbanization (`AVERAGE of prop_n`)
# - Water tax, time, interruptions, and surface water usage
#
# ####  Key Insights:
# - **Low-income countries** have the highest population burden and longest water retrieval times (16.5 minutes on average).
# - They also face the most interruptions and highest surface water reliance (5.42%).
# - **High-income countries** have minimal interruptions and surface water usage, with nearly 100% basic access.
#
# ####  Policy Insight:
# - **Infrastructure investment** should prioritize low-income countries with high rural populations and poor access.
# - **Urbanization** is a strong predictor of improved water access — policies should support sustainable urban growth.
# - **Income group targeting** enables more equitable resource allocation and SDG 6 progress.
